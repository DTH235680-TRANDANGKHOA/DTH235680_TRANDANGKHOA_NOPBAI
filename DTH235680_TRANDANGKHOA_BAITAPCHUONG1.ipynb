# %%
print('hello world!');
# Out:
# hello world!

# %%
print('Albert Einstein da tung noi: một người không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.')
# Out:
# Albert Einstein da tung noi: một người không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.

# %%
if (5>2)
print(' Five is greater than two!')
# Out:
#   File "/tmp/ipython-input-3687740902.py", line 1
#     if (5>2)
#             ^
# SyntaxError: expected ':'

# %%
total =1+\
2+\
3
print(total); print('hello Python!')
# Out:
# 6
# hello Python!

# %%
if true:
print('true')
else:
print('false')
# Out:
#   File "/tmp/ipython-input-2948870049.py", line 2
#     print('true')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
#this is a comment
print('hello, world')
# Out:
# hello, world

# %%
import math
import os

# %%
def add(a,b):
result =a+b
return result
# Out:
#   File "/tmp/ipython-input-1657333215.py", line 2
#     result =a+b
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
#module1.py
question=' what is the meaning of life, the Universe,
And Everything?'
answer=42
#module2.py
question='what is your question?'
answer='to seek the holy grail.'
import module1
import module2
print(module1.question)
print(module2.question)
print(module1.answer)
print(module1.answer)
# Out:
#   File "/tmp/ipython-input-1552081460.py", line 2
#     question=' what is the meaning of life, the Universe,
#              ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
import math_libs
math_libs.add(4,5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-702332260.py in <cell line: 0>()
# ----> 1 import math_libs
#       2 math_libs.add(4,5)
#
# ModuleNotFoundError: No module named 'math_libs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
